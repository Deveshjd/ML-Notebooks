# %% [markdown]
# <a href="https://colab.research.google.com/github/Deveshjd/ML-Notebooks/blob/main/MLDStraining2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns

# %%
# Matrics --> collection of vectors

# %%
np.array([10,20,30,23])
# Out:
# array([10, 20, 30, 23])

# %%
arr = np.array([[1,2,3,4],
                [4,5,6,8],
                [6,7,8,9],
                [8,9,0,1]])
arr
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 8],
#        [6, 7, 8, 9],
#        [8, 9, 0, 1]])

# %%
arr.shape     #(row, col)
# Out:
# (4, 4)

# %%
arr.size
# Out:
# 16

# %%
len(arr)   #no. of vectors i.e 4
# Out:
# 4

# %%
arr.ndim   #dimension
# Out:
# 2

# %%
# silceing --> arr[row_slicing, col_slicing]

# %%
arr
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 8],
#        [6, 7, 8, 9],
#        [8, 9, 0, 1]])

# %%
arr[0:2, 0:2]
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
arr[1::, 1:3]
# Out:
# array([[5, 6],
#        [7, 8],
#        [9, 0]])

# %%
arr[::-3, 1:3:]
# Out:
# array([[9, 0],
#        [2, 3]])

# %%
arr
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 8],
#        [6, 7, 8, 9],
#        [8, 9, 0, 1]])

# %%
arr[::3, ::3]
# Out:
# array([[1, 4],
#        [8, 1]])

# %%
arr[::3, 1:3:]
# Out:
# array([[2, 3],
#        [9, 0]])

# %%
np.random.randint(1,24,30)
# Out:
# array([ 5, 21, 15,  8, 10, 19, 22,  3, 20,  8,  6, 10,  7,  4,  1, 10, 23,
#         2,  1,  3, 15, 13, 19,  7, 12, 10,  5, 19, 18,  9])

# %%
new_arr = np.random.randint(0,20,100).reshape(10,10)

# %%
new_arr
# Out:
# array([[16,  7, 11, 16, 14, 17, 10, 11, 17,  4],
#        [ 6, 19,  2, 11, 14, 19, 14,  4, 16,  1],
#        [ 4,  1,  4, 14, 14,  0, 16,  2,  7, 18],
#        [11, 18, 15, 15,  1, 12, 19,  4,  5,  4],
#        [18, 16, 10,  3, 17, 14, 13,  3,  1,  1],
#        [16,  6, 13, 12,  5, 17, 18, 18,  7, 14],
#        [ 2, 19,  6, 17,  5, 11,  0, 12,  9, 15],
#        [ 8,  5,  2,  9, 17,  8, 16, 12, 16, 13],
#        [ 3, 13,  5,  7, 17,  8,  9,  1, 15, 12],
#        [13, 11, 11,  8,  9, 11, 18,  7,  3, 18]])

# %%
new_arr[7:10, 5:8]
# Out:
# array([[ 8, 16, 12],
#        [ 8,  9,  1],
#        [11, 18,  7]])

# %%
# Out:
# array([[18,  3,  7, 18, 11,  9,  8, 11, 11, 13],
#        [12, 15,  1,  9,  8, 17,  7,  5, 13,  3],
#        [13, 16, 12, 16,  8, 17,  9,  2,  5,  8],
#        [15,  9, 12,  0, 11,  5, 17,  6, 19,  2],
#        [14,  7, 18, 18, 17,  5, 12, 13,  6, 16],
#        [ 1,  1,  3, 13, 14, 17,  3, 10, 16, 18],
#        [ 4,  5,  4, 19, 12,  1, 15, 15, 18, 11],
#        [18,  7,  2, 16,  0, 14, 14,  4,  1,  4],
#        [ 1, 16,  4, 14, 19, 14, 11,  2, 19,  6],
#        [ 4, 17, 11, 10, 17, 14, 16, 11,  7, 16]])

# %%
sns.histplot(new_arr)
# Out:
# <Axes: ylabel='Count'>
