# %% [markdown]
# <a href="https://colab.research.google.com/github/Deveshjd/ML-Notebooks/blob/main/working_with_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as mp
import pandas as pd
import seaborn as sns

# %%
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data["sex"].shape[0]
# Out:
# 244

# %%
# How many male came on thursday
data[(data["sex"] == "Male") & (data["day"] == "Thur")].shape[0]
# Out:
# 30

# %%
# Average tip given by all males
data[data["sex"] == "Male"]["tip"].mean()
# Out:
# np.float64(3.0896178343949043)

# %%
# No. of female smokers
data[(data["sex"] == "Female") & (data["smoker"] == "Yes")].shape[0]
# Out:
# 33

# %%
# Average size of female group
data[data["sex"] == "Female"]["size"].mean(). astype(int)
# Out:
# np.int64(2)

# %%
# Average bill paid on sunday
data[data["day"] == "Sun"]["total_bill"].mean()
# Out:
# np.float64(21.41)

# %%
# Highest bill ever paid for dinner
data[data["time"] == "Dinner"]["total_bill"].max()
# Out:
# 50.81

# %%
# Higest no. of smokers visited on which day
for i in data["day"].value_counts().index:
  print(f"{i} --> {data[(data["smoker"] == "Yes") & (data['day'] == i)].shape[0]}")
# Out:
# Sat --> 42
# Sun --> 19
# Thur --> 17
# Fri --> 15

# %%
# compare no. of females visited for lunch and dinner
for i in data["time"].value_counts().index:
  print(f"{i} --> {data[data["sex"] == "Female"].shape[0]}")
# Out:
# Dinner --> 87
# Lunch --> 87

# %%
# what time does the non smokers prefer(lunch, dinner)
for i in data["time"].value_counts().index:
  print(f"{i} --> {data[(data["smoker"] == "No") & (data["time"] == i)].shape[0]}")
# Out:
# Dinner --> 106
# Lunch --> 45

# %%
data[(data["sex"] == "Male") & (data["day" == "thu"])].value_counts()

# %%
for i in data["day"].value_counts().index:
  print(f"{i} --> {data[(data["smoker"] == "Yes") & (data['day'] == i)].shape[0]}")
# Out:
# Sat --> 42
# Sun --> 19
# Thur --> 17
# Fri --> 15

# %%
data["size"].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
# sabse zyada tip male ne di ya female ne

data[(data["sex"] == "Male") & (data["tip"] == data["tip"].max())]["tip"]

# data["tip"].max()
# Out:
# 170    10.0
# Name: tip, dtype: float64

# %%
# sabse zyada smoking male ne kri ya female ne

for i in data["sex"].value_counts().index:
  print(f"{i} --> {data[(data["sex"] == i) & (data["smoker"] == "Yes")].shape[0]}")
# Out:
# Male --> 60
# Female --> 33

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("tips")
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data["size"].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (244, 7)

# %%
data["size"].shape[0]
# Out:
# 244

# %%
data["size"].value_counts().index
# Out:
# Index([2, 3, 4, 5, 1, 6], dtype='int64', name='size')

# %%
data["size"].value_counts().values
# Out:
# array([156,  38,  37,   5,   4,   4])

# %%
data["size"].value_counts().index[0]
# Out:
# np.int64(2)

# %%
data["size"].value_counts().shape[0]
# Out:
# 6

# %%
# On which day most smokers come:

for i in data["day"].value_counts().index:
  print(f"{i} --> {data[(data['smoker'] == 'Yes') & (data["day"] == i)].shape[0]}")
# Out:
# Sat --> 42
# Sun --> 19
# Thur --> 17
# Fri --> 15

# %%
data["day"].groupby(data["smoker"]).value_counts()
# Out:
# /tmp/ipykernel_6400/250512116.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data["day"].groupby(data["smoker"]).value_counts()
# smoker  day
# Yes     Sat     42
#         Sun     19
#         Thur    17
#         Fri     15
# No      Sun     57
#         Thur    45
#         Sat     45
#         Fri      4
# Name: count, dtype: int64

# %%
# lazy evaluation
# eager eval
# iterator and generator

# %%
data.groupby("day").value_counts().index
# Out:
# /tmp/ipykernel_6400/1812901181.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby("day").value_counts().index
# MultiIndex([('Thur',  13.0,  2.0, 'Female', 'Yes',  'Lunch', 2),
#             ('Thur',  7.51,  2.0,   'Male',  'No',  'Lunch', 2),
#             ('Thur',  7.56, 1.44,   'Male',  'No',  'Lunch', 2),
#             ('Thur',  8.35,  1.5, 'Female',  'No',  'Lunch', 2),
#             ('Thur',  8.51, 1.25, 'Female',  'No',  'Lunch', 2),
#             ('Thur',  8.52, 1.48,   'Male',  'No',  'Lunch', 2),
#             ('Thur',  9.78, 1.73,   'Male',  'No',  'Lunch', 2),
#             ('Thur', 10.07, 1.83, 'Female',  'No',  'Lunch', 1),
#             ('Thur', 10.33,  2.0, 'Female',  'No',  'Lunch', 2),
#             ('Thur', 10.34,  2.0,   'Male', 'Yes',  'Lunch', 2),
# ...

# %%
data.groupby(data["day"]).value_counts().index
# Out:
# /tmp/ipykernel_6400/1263220873.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby(data["day"]).value_counts().index
# MultiIndex([('Thur',  13.0,  2.0, 'Female', 'Yes',  'Lunch', 2),
#             ('Thur',  7.51,  2.0,   'Male',  'No',  'Lunch', 2),
#             ('Thur',  7.56, 1.44,   'Male',  'No',  'Lunch', 2),
#             ('Thur',  8.35,  1.5, 'Female',  'No',  'Lunch', 2),
#             ('Thur',  8.51, 1.25, 'Female',  'No',  'Lunch', 2),
#             ('Thur',  8.52, 1.48,   'Male',  'No',  'Lunch', 2),
#             ('Thur',  9.78, 1.73,   'Male',  'No',  'Lunch', 2),
#             ('Thur', 10.07, 1.83, 'Female',  'No',  'Lunch', 1),
#             ('Thur', 10.33,  2.0, 'Female',  'No',  'Lunch', 2),
#             ('Thur', 10.34,  2.0,   'Male', 'Yes',  'Lunch', 2),
# ...

# %%
ind = data.groupby("day").groups
ind
# Out:
# /tmp/ipykernel_6400/3813916111.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ind = data.groupby("day").groups
# ...

# %%
ind["Thur"]
# Out:
# Index([ 77,  78,  79,  80,  81,  82,  83,  84,  85,  86,  87,  88,  89, 117,
#        118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131,
#        132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145,
#        146, 147, 148, 149, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200,
#        201, 202, 203, 204, 205, 243],
#       dtype='int64')

# %%
data.iloc[ind["Thur"]]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 77        27.20  4.00    Male     No  Thur   Lunch     4
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [62 rows x 7 columns]

# %%
data.groupby("day")["tip"].mean()
# Out:
# /tmp/ipykernel_6400/3508396809.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby("day")["tip"].mean()
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
data.groupby("day")["tip"].agg(["mean", "median", "sum"])
# Out:
# /tmp/ipykernel_6400/4239739830.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby("day")["tip"].agg(["mean", "median", "sum"])
#           mean  median     sum
# day
# Thur  2.771452   2.305  171.83
# Fri   2.734737   3.000   51.96
# Sat   2.993103   2.750  260.40
# Sun   3.255132   3.150  247.39

# %%
data.groupby("sex")["tip"].agg(["mean", "median", "sum"])
# Out:
# /tmp/ipykernel_6400/2245297363.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby("sex")["tip"].agg(["mean", "median", "sum"])
#             mean  median     sum
# sex
# Male    3.089618    3.00  485.07
# Female  2.833448    2.75  246.51

# %%
data.groupby(["day", "size"])["tip"].mean()
# Out:
# /tmp/ipykernel_6400/1718758377.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby(["day", "size"])["tip"].mean()
# day   size
# Thur  1       1.830000
#       2       2.442500
#       3       2.692500
#       4       4.218000
#       5       5.000000
#       6       5.300000
# Fri   1       1.920000
#       2       2.644375
#       3       3.000000
#       4       4.730000
#       5            NaN
#       6            NaN
# Sat   1       1.000000
#       2       2.517547
#       3       3.797778
#       4       4.123846
#       5       3.000000
#       6            NaN
# Sun   1            NaN
#       2       2.816923
#       3       3.120667
#       4       4.087778
#       5       4.046667
#       6       5.000000
# Name: tip, dtype: float64

# %%
data.groupby("day")["tip"].mean()
# Out:
# /tmp/ipykernel_6400/3508396809.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby("day")["tip"].mean()
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64
