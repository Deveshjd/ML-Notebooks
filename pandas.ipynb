# %% [markdown]
# <a href="https://colab.research.google.com/github/Deveshjd/ML-Notebooks/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/root/.cache/kagglehub/datasets/mczielinski/bitcoin-historical-data/versions/696/btcusd_1-min_data.csv")

# %%
data.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume
# 0  1325376060  4.58  4.58  4.58   4.58     0.0
# 1  1325376120  4.58  4.58  4.58   4.58     0.0
# 2  1325376180  4.58  4.58  4.58   4.58     0.0
# 3  1325376240  4.58  4.58  4.58   4.58     0.0
# 4  1325376300  4.58  4.58  4.58   4.58     0.0

# %%
pd.Series({
    0:100, 1:300, 2:500, 3:1000
})
# Out:
# 0     100
# 1     300
# 2     500
# 3    1000
# dtype: int64

# %%
pd.Series({
    "A":100, "B":300, "C":500, "D":1000
})
# Out:
# A     100
# B     300
# C     500
# D    1000
# dtype: int64

# %%
arr = np.array([10,20,30])
arr
# Out:
# array([10, 20, 30])

# %%
s = pd.Series(arr)

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
arr[0] = 10000 # changing value of arr also changes the value of series

# %%
arr
# Out:
# array([10000,    20,    30])

# %%
s
# Out:
# 0    10000
# 1       20
# 2       30
# dtype: int64

# %%
s_copy = pd.Series(arr, copy = True)

# %%
arr[0] = 1234

# %%
arr
# Out:
# array([1234,   20,   30])

# %%
s_copy
# Out:
# 0    10000
# 1       20
# 2       30
# dtype: int64

# %%
s1 = pd.Series([1,23,4,5,6,7])

# %%
s2 = s_copy + s1

# %%
s2
# Out:
# 0    10003.0
# 1       89.0
# 2       42.0
# 3        NaN
# 4        NaN
# 5        NaN
# dtype: float64

# %% [markdown]
# **Index**
#
# 1.   Default index --> Automatically ==> iloc (integer location)
# 2.   label index --> user defined

# %%
s2.iloc[1]
# Out:
# np.float64(89.0)

# %%
s2.iloc[-1]
# Out:
# np.float64(nan)

# %%
s2[s2>80]
# Out:
# 0    10003.0
# 1       89.0
# dtype: float64

# %%
s2>80
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
s2.iloc[0:3]
# Out:
# 0    10003.0
# 1       89.0
# 2       42.0
# dtype: float64

# %%
s2.iloc[[0,1,2]]
# Out:
# 0    10003.0
# 1       89.0
# 2       42.0
# dtype: float64

# %%
s3 = pd.Series([10,20,304,40,50,607,7080,500])
s3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_959/2615658560.py in <cell line: 0>()
# ----> 1 s3 = pd.Series([10,20,304,40,50,607,7080,500])
#       2 s3
#
# NameError: name 'pd' is not defined

# %%
s3.iloc[::7]
# Out:
# 0     10
# 7    500
# dtype: int64

# %%
s3.iloc[[0,7]]
# Out:
# 0     10
# 7    500
# dtype: int64

# %%
s4 = pd.Series([1,3,4,5,6,7], index=["a","b","c","z","d","j"])

# %%
s4
# Out:
# a    1
# b    3
# c    4
# z    5
# d    6
# j    7
# dtype: int64

# %%
s4.iloc[0]
# Out:
# np.int64(1)

# %%
s4.iloc["a"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1110/96455644.py in <cell line: 0>()
# ----> 1 s4.iloc["a"]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1747             key = item_from_zerodim(key)
#    1748             if not is_integer(key):
# -> 1749                 raise TypeError("Cannot index by location index with a non-integer key")
#    1750
#    1751             # validate the location
#
# ...

# %%
s4.iloc[0:3]
# Out:
# a    1
# b    3
# c    4
# dtype: int64

# %%
s4.loc["a":"c"]
# Out:
# a    1
# b    3
# c    4
# dtype: int64

# %%
s4[0]
# Out:
# /tmp/ipykernel_1110/957271931.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s4[0]
# np.int64(1)

# %%
s4.iloc[0]
# Out:
# np.int64(1)

# %%
s4.loc["a"]
# Out:
# np.int64(1)

# %%
s5 = pd.Series([2,3,4,5,6,7])
s5
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
print(s5.iloc[0])
print(s5.loc[0])
# Out:
# 2
# 2

# %%
print(s5.iloc[0:3])
print()
print(s5.loc[0:3])
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64
#
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
s5[0]+10
# Out:
# np.int64(12)

# %%
s5
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
s5.loc[:-1]
# Out:
# Series([], dtype: int64)

# %%
s5.iloc[:-1]
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
s5.iloc[:-2]
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
s5.loc[0]
# Out:
# np.int64(2)

# %%
s5.mean()
# Out:
# np.float64(4.5)

# %%
s5.median()
# Out:
# 4.5

# %%
s5.count()
# Out:
# np.int64(6)

# %%
s5.size
# Out:
# 6

# %%
s5.ndim
# Out:
# 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s5
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
sns.histplot(s5)
plt.show()

# %%
sns.lineplot(s5)
# Out:
# <Axes: >

# %%
d = np.random.rand(10)
d
# Out:
# array([0.48530031, 0.06399884, 0.38289764, 0.59392649, 0.64796914,
#        0.08540345, 0.61292859, 0.32340042, 0.74061761, 0.97613567])
